# %%
# Import dependencies
from splinter import Browser
from bs4 import BeautifulSoup as soup
import pandas as pd

# %%
# Path to chromedriver (using a Macbook Pro)
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path':'/usr/local/bin/chromedriver'}
browser = Browser('chrome',**executable_path)

# %%
# Go to site with draft data
url = "https://basketball.realgm.com/ncaa/stats/2018/Averages/Qualified/All/Season/All/points/desc/1/"
browser.visit(url)

# %%
df = pd.read_html(url)
stats_df = df[0]
stats_df
# Out:
#       #            Player  Team  GP   MPG   FGM   FGA    FG%  3PM  3PA  ...  \
# 0     1   Reggie Williams   VMI  33  32.4  10.2  19.3  0.531  2.3  7.2  ...
# 1     2      Trey Johnson   JSU  35  37.8   8.9  21.5  0.414  2.3  6.8  ...
# 2     3     Morris Almond    RU  32  33.5   8.2  17.0  0.483  2.4  5.3  ...
# 3     4      Kevin Durant    UT  35  35.9   8.7  18.5  0.472  2.3  5.8  ...
# 4     5         Gary Neal    TU  32  36.5   8.3  18.7  0.446  2.9  8.7  ...
# ..  ...               ...   ...  ..   ...   ...   ...    ...  ...  ...  ...
# 95   96  Courtney Bradley   JSU  30  32.7   6.2  13.5  0.462  1.1  3.1  ...
# 96   97     Derrick Byars    VU  34  31.4   6.1  13.3  0.457  2.3  6.2  ...
# 97   98       Kyle Visser    WF  31  29.0   6.1  10.4  0.584  0.0  0.1  ...
# 98   99     Keith Simmons    HC  34  35.6   5.6  11.2  0.497  1.5  4.3  ...
# 99  100       Quinton Day  UMKC  32  36.9   5.7  14.2  0.399  2.9  7.6  ...
#
#       FT%  TOV   PF  ORB  DRB   RPG  APG  SPG  BPG   PPG
# ...

# %%
stats_df.columns
# Out:
# Index(['#', 'Player', 'Team', 'GP', 'MPG', 'FGM', 'FGA', 'FG%', '3PM', '3PA',
#        '3P%', 'FTM', 'FTA', 'FT%', 'TOV', 'PF', 'ORB', 'DRB', 'RPG', 'APG',
#        'SPG', 'BPG', 'PPG'],
#       dtype='object')

# %%
#Create empty dataframe to hold all scraped info
full_stats_df = pd.DataFrame(columns=['#', 'Player', 'Team', 'GP', 'MPG', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'TOV', 'PF', 'ORB', 'DRB', 'RPG', 'APG', 'SPG', 'BPG', 'PPG'])


for page in range(1,21):
    url = f"https://basketball.realgm.com/ncaa/stats/2018/Averages/Qualified/All/Season/All/points/desc/{page}/"
    
    df = pd.read_html(url)
    stats_df = df[0]

    full_stats_df = full_stats_df.append(stats_df, ignore_index=True)
    print(f"Complete page number: {page}")

full_stats_df
# Out:
# Complete page number: 1
# Complete page number: 2
# Complete page number: 3
# Complete page number: 4
# Complete page number: 5
# Complete page number: 6
# Complete page number: 7
# Complete page number: 8
# Complete page number: 9
# Complete page number: 10
# Complete page number: 11
# Complete page number: 12
# Complete page number: 13
# Complete page number: 14
# Complete page number: 15
# Complete page number: 16
# Complete page number: 17
# Complete page number: 18
# Complete page number: 19
# Complete page number: 20
#          #                 Player     Team  GP   MPG  FGM   FGA    FG%  3PM  \
# 0        1             Trae Young       OU  32  35.4  8.2  19.3  0.422  3.7
# 1        2          Kendrick Nunn       OU  30  37.9  8.7  20.1  0.435  4.5
# 2        3          Jordan Howard      UCA  35  36.0  8.0  17.5  0.457  3.2
# 3        4          Chris Clemons      CAM  31  34.0  7.5  16.6  0.452  3.1
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(full_stats_df)
# Out:
#          #                          Player     Team  GP   MPG  FGM   FGA  \
# 0        1                      Trae Young       OU  32  35.4  8.2  19.3
# 1        2                   Kendrick Nunn       OU  30  37.9  8.7  20.1
# 2        3                   Jordan Howard      UCA  35  36.0  8.0  17.5
# 3        4                   Chris Clemons      CAM  31  34.0  7.5  16.6
# 4        5           Justin Wright-Foreman      HOF  31  37.8  8.5  19.0
# 5        6                       Mike Daum     SDSU  35  31.1  7.8  16.9
# 6        7                       R.J. Cole       HU  33  37.9  7.3  18.5
# 7        8             Demontrae Jefferson      TSU  27  37.6  7.7  18.3
# 8        9                      Jon Elmore       MU  36  38.3  6.8  15.4
# 9       10                    Bryson Scott     IPFW  33  31.1  7.5  16.4
# 10      11                    Andre Spight      UNC  38  33.8  7.7  17.4
# 11      12                     Matt Morgan      COR  28  34.6  7.3  14.8
# ...

# %%
for name in full_stats_df["Player"]:
    if len(name.split()) > 2:
        print(name)
# Out:
# Marvin Bagley III
# Kyle Allman, Jr.
# James Batemon III
# Frank Bartley, IV
# Wesley Person, Jr.
# Dachon Burke, Jr.
# Desmond Cambridge, Jr.
# Otis Livingston II
# James Palmer, Jr.
# Ivy Smith, Jr.
# Brian Beard, Jr.
# David Jenkins, Jr.
# Barry Brown, Jr.
# Melvin Frazier, Jr.
# Leland King II
# Akwasi Abeyie Yeboah
# T.J. Shorts II
# Christopher Galbreath, Jr.
# Lance Tejada, Jr.
# Gary Trent, Jr.
# James Thompson IV
# Eric Williams, Jr.
# Lavone Holland II
# Wendell Carter, Jr.
# Darrell Brown, Jr.
# Edward Polite, Jr.
# Jon Axel Gudmundsson
# Daxter Miles, Jr.
# Steven Haney, Jr.
# Emmanuel Chukwubuikem Nzekwesi
# Marvin Clark Jr.
# Kerry Blackshear, Jr.
# Olin Carter III
# Kerwin Roach, Jr.
# Marcus Shaver, Jr.
# Ferron Flavors, Jr.
# Adonis De La Rosa
# John Davis III
# Troy Brown, Jr.
# Lovell Cabbil, Jr.
# Jaren Jackson, Jr.
# Phlandrous Fleming, Jr.
# Corey Henderson, Jr.
# Jermaine Jackson, Jr.
# Keith Fisher III
# Marlon Hunter, Jr.
# John Petty, Jr.
# Matt Coleman III
# ...

# %%
full_stats_df["Player"] = full_stats_df["Player"].str.replace('Jr.','')
full_stats_df.iloc[40:60]
# Out:
#      #              Player    Team  GP   MPG  FGM   FGA    FG%  3PM  3PA  ...  \
# 40  41       Aaron Holiday    UCLA  33  37.7  6.4  13.9  0.461  2.7  6.2  ...
# 41  42          Nick Dixon   UTRGV  33  29.6  6.0  13.3  0.448  1.6  4.6  ...
# 42  43        Jairus Lyles    UMBC  33  34.9  6.8  15.5  0.439  2.4  6.1  ...
# 43  44       Deandre Ayton  U of A  35  33.5  7.9  12.9  0.612  0.3  1.0  ...
# 44  45         Zach Lofton    NMSU  33  31.9  6.6  14.4  0.456  2.6  6.9  ...
# 45  46          C.J. Burks      MU  35  35.9  7.4  15.7  0.472  2.5  6.7  ...
# 46  47  Chandler Hutchison     BSU  31  31.0  6.6  13.9  0.475  1.5  4.1  ...
# 47  48         Zane Martin      TU  32  30.2  7.1  15.4  0.458  2.2  5.8  ...
# 48  49       Marcus Foster      CU  33  31.6  7.5  15.4  0.483  2.9  7.0  ...
# 49  50    Keita Bates-Diop     OSU  34  33.1  7.3  15.1  0.480  1.9  5.4  ...
# 50  51        Roddy Peters     NSU  32  26.8  7.2  13.9  0.515  0.3  1.2  ...
# ...

# %%
for name in full_stats_df["Player"]:
    if len(name.split()) > 2:
        print(name)
# Out:
# Marvin Bagley III
# Kyle Allman Jr.
# James Batemon III
# Frank Bartley IV
# Wesley Person Jr.
# Dachon Burke Jr.
# Desmond Cambridge Jr.
# Otis Livingston II
# James Palmer Jr.
# Ivy Smith Jr.
# Brian Beard Jr.
# David Jenkins Jr.
# Barry Brown Jr.
# Melvin Frazier Jr.
# Leland King II
# Akwasi Abeyie Yeboah
# T.J. Shorts II
# Christopher Galbreath Jr.
# Lance Tejada Jr.
# Gary Trent Jr.
# James Thompson IV
# Eric Williams Jr.
# Lavone Holland II
# Wendell Carter Jr.
# Darrell Brown Jr.
# Edward Polite Jr.
# Jon Axel Gudmundsson
# Daxter Miles Jr.
# Steven Haney Jr.
# Emmanuel Chukwubuikem Nzekwesi
# Marvin Clark Jr.
# Kerry Blackshear Jr.
# Olin Carter III
# Kerwin Roach Jr.
# Marcus Shaver Jr.
# Ferron Flavors Jr.
# Adonis De La Rosa
# John Davis III
# Troy Brown Jr.
# Lovell Cabbil Jr.
# Jaren Jackson Jr.
# Phlandrous Fleming Jr.
# Corey Henderson Jr.
# Jermaine Jackson Jr.
# Keith Fisher III
# Marlon Hunter Jr.
# John Petty Jr.
# Matt Coleman III
# Ray Ona Embo
# John Dewey III
# ...

# %%
full_stats_df
# Out:
#          #                 Player     Team  GP   MPG  FGM   FGA    FG%  3PM  \
# 0        1             Trae Young       OU  32  35.4  8.2  19.3  0.422  3.7
# 1        2          Kendrick Nunn       OU  30  37.9  8.7  20.1  0.435  4.5
# 2        3          Jordan Howard      UCA  35  36.0  8.0  17.5  0.457  3.2
# 3        4          Chris Clemons      CAM  31  34.0  7.5  16.6  0.452  3.1
# 4        5  Justin Wright-Foreman      HOF  31  37.8  8.5  19.0  0.449  3.1
# ...    ...                    ...      ...  ..   ...  ...   ...    ...  ...
# 1995  1996      Christian Carlyle      FGC  27  18.7  1.7   4.0  0.431  0.3
# 1996  1997            Nick Rogers    IUPUI  27  23.5  1.5   4.4  0.333  0.6
# 1997  1998         Elijah Schmidt  TAMU-CC  29  22.0  2.0   3.9  0.504  0.1
# 1998  1999            Tom Capuano      MAN  31  22.7  2.0   4.0  0.496  1.0
# 1999  2000           Xavier Green      ODU  31  22.3  1.8   4.6  0.387  0.5
#
# ...

# %%
full_stats_df["Year"] = f'2018'
full_stats_df
# Out:
#          #                 Player     Team  GP   MPG  FGM   FGA    FG%  3PM  \
# 0        1             Trae Young       OU  32  35.4  8.2  19.3  0.422  3.7
# 1        2          Kendrick Nunn       OU  30  37.9  8.7  20.1  0.435  4.5
# 2        3          Jordan Howard      UCA  35  36.0  8.0  17.5  0.457  3.2
# 3        4          Chris Clemons      CAM  31  34.0  7.5  16.6  0.452  3.1
# 4        5  Justin Wright-Foreman      HOF  31  37.8  8.5  19.0  0.449  3.1
# ...    ...                    ...      ...  ..   ...  ...   ...    ...  ...
# 1995  1996      Christian Carlyle      FGC  27  18.7  1.7   4.0  0.431  0.3
# 1996  1997            Nick Rogers    IUPUI  27  23.5  1.5   4.4  0.333  0.6
# 1997  1998         Elijah Schmidt  TAMU-CC  29  22.0  2.0   3.9  0.504  0.1
# 1998  1999            Tom Capuano      MAN  31  22.7  2.0   4.0  0.496  1.0
# 1999  2000           Xavier Green      ODU  31  22.3  1.8   4.6  0.387  0.5
#
# ...
